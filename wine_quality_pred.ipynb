# %%
import pandas as pd

# %%
df = pd.read_csv(r"D:\Data Science\datasets\winequality-red.csv")

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df.shape
# Out:
# (1599, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
df.isna().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.catplot(x="quality",data=df,kind="count")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
plt.figure(figsize=(5,5))
sns.barplot(x="quality",y="volatile acidity",data=df)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x="quality",y="chlorides",data=df)
plt.show()

# %%
plt.figure(figsize=(12,10))
sns.heatmap(df.corr(),annot=True,cmap="coolwarm")
plt.title("Features correlation heatmap")
# Out:
# Text(0.5, 1.0, 'Features correlation heatmap')

# %%
selected_col = ['volatile acidity','citric acid','sulphates','alcohol','quality']

# %%
new_df = df[selected_col]

# %%
new_df.head(15)
# Out:
#     volatile acidity  citric acid  sulphates  alcohol  quality
# 0              0.700         0.00       0.56      9.4        5
# 1              0.880         0.00       0.68      9.8        5
# 2              0.760         0.04       0.65      9.8        5
# 3              0.280         0.56       0.58      9.8        6
# 4              0.700         0.00       0.56      9.4        5
# 5              0.660         0.00       0.56      9.4        5
# 6              0.600         0.06       0.46      9.4        5
# 7              0.650         0.00       0.47     10.0        7
# 8              0.580         0.02       0.57      9.5        7
# 9              0.500         0.36       0.80     10.5        5
# 10             0.580         0.08       0.54      9.2        5
# 11             0.500         0.36       0.80     10.5        5
# 12             0.615         0.00       0.52      9.9        5
# 13             0.610         0.29       1.56      9.1        5
# ...

# %%
x = new_df.drop(columns='quality',axis=1)
y = new_df['quality']

# %%
y = y.apply(lambda x:1 if x >= 7 else 0)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model = RandomForestClassifier(n_estimators=100,random_state=42)

# %%
model.fit(x_train,y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
acc = accuracy_score(y_test,y_pred)

# %%
print(acc)
# Out:
# 0.8875

# %%
result = model.predict([[0.70,0.00,0.56,9.4]])
# Out:
# d:\projects\wine-quality-prediction\venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %%
if result == 0:
    print(result[0],"Wine quality is bad")
else:
    print(result[0],"Wine quality is good")
# Out:
# 0 Wine quality is bad

# %%
import pickle

# %%
with open("wine_quality_pred.pkl",'wb') as f:
    pickle.dump(model,f)
